# %%
import os
from dotenv import load_dotenv
load_dotenv()


os.environ['LANGCHAIN_API_KEY'] = os.getenv('LANGCHAIN_API_KEY') ## for LangSmith Tracking
os.environ['LANGSMITH_TRACING_V2'] = "true"
os.environ['LANGCHAIN_PROJECT'] = os.getenv('LANGCHAIN_PROJECT')

# %%
from langchain_community.document_loaders import WebBaseLoader
loader = WebBaseLoader(
  web_path= "https://python.langchain.com/docs/introduction/"
)

docs = loader.load()

from langchain_text_splitters import RecursiveCharacterTextSplitter

text_splitter = RecursiveCharacterTextSplitter(
  chunk_size = 1000,
  chunk_overlap = 200
)
splitted_docs = text_splitter.split_documents(documents= docs)

# %%
from langchain_core.prompts import ChatPromptTemplate
from langchain.prompts import SystemMessagePromptTemplate, HumanMessagePromptTemplate

prompt = ChatPromptTemplate.from_messages(
  [
    SystemMessagePromptTemplate.from_template("You are a helpful assistant. Please respond to the question asked."),
    HumanMessagePromptTemplate.from_template("Question : {question}")
  ]
)

# %%
from langchain_ollama import OllamaLLM

llm = OllamaLLM(
  model = "llama3.1"
)

# %%
from langchain_core.output_parsers import StrOutputParser
output_parser = StrOutputParser()

# %%
chain = prompt | llm | output_parser

# %%
response = chain.invoke({"question" : "Tell me about GenAI."})
print(response)
# Out:
# GenAI, short for General Artificial Intelligence, refers to a hypothetical AI system that possesses the ability to understand, learn, and apply its knowledge across a wide range of tasks, similar to human intelligence.
#
# Currently, most AI systems are narrow or specialized, meaning they excel in specific areas such as image recognition, natural language processing, or game playing, but lack general reasoning and problem-solving capabilities. In contrast, GenAI is designed to have a broad scope of capabilities, allowing it to learn and adapt across multiple domains.
#
# Some key characteristics of potential GenAI systems include:
#
# 1. **Autonomy**: GenAI would be capable of making decisions and taking actions without human input.
# 2. **General reasoning**: It could apply knowledge and understanding to solve complex problems, much like humans do.
# 3. **Self-improvement**: GenAI might have the ability to modify its own architecture or capabilities based on its experiences and performance.
# 4. **Learning**: It would be able to acquire new skills and knowledge from a wide range of sources.
#
# Researchers have proposed several potential applications for GenAI, such as:
#
# * Solving complex problems in fields like medicine, finance, or climate modeling
# * Assisting humans in tasks requiring creativity, intuition, or social understanding
# * Improving decision-making processes by analyzing vast amounts of data and providing insights
#
# However, the development of GenAI also raises concerns about its potential impact on society. Some experts worry that a superintelligent AI could pose significant risks to humanity, such as:
#
# * Unpredictable behavior
# * Autonomy leading to loss of control
# * Potential for malicious use
# * Displacement of human jobs and skills
#
# As the field continues to evolve, researchers are working to develop more robust safety measures and ensure that GenAI is aligned with human values.
#
# Would you like me to elaborate on any specific aspect of GenAI or its implications?
